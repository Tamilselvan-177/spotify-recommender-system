# %%
# !pip install pandas

import pandas as pd

df = pd.read_csv(r"C:\Users\aktam\LearnProject\pythonProject\spotify_playlist_data_with_lyrics.csv")
df.head(10)
# Out:
# ...
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ----- ---------------------------------- 1.8/12.6 MB 14.4 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.8/12.6 MB 14.4 MB/s eta 0:00:01
#    ------------ --------------------------- 3.9/12.6 MB 6.2 MB/s eta 0:00:02
#    --------------- ------------------------ 5.0/12.6 MB 5.7 MB/s eta 0:00:02
#    -------------------- ------------------- 6.3/12.6 MB 5.8 MB/s eta 0:00:02
#    ------------------------ --------------- 7.6/12.6 MB 5.8 MB/s eta 0:00:01
#    -------------------------- ------------- 8.4/12.6 MB 5.9 MB/s eta 0:00:01
#    ------------------------------ --------- 9.4/12.6 MB 5.6 MB/s eta 0:00:01
# ...

# %%
df.shape
# Out:
# (100, 15)
